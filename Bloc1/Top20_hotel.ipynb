# %% [markdown]
# ### Import des bibliothéques
# ---

# %%
import pandas as pd

# %% [markdown]
# ### Chargement des données
# ---

# %%
df_top20 = pd.read_csv('df_hotel.csv')
df_top20.head()
# Out:
#            ville                                               name  \
# 0  Aigues Mortes  La Perle Rose Villa Standing 5 étoiles avec pi...
# 1  Aigues Mortes                               Ô 36 Rempart Sud B&B
# 2  Aigues Mortes               2 Bedroom Cozy Home In Aigues-Mortes
# 3  Aigues Mortes                                            Evasion
# 4  Aigues Mortes          La maison sur la place dans Aigues Mortes
#
#                                          description  \
# 0  Situé à Aigues-Mortes, l’hébergement La Perle ...
# 1  L’établissement Ô 36 Rempart Sud B&B se trouve...
# 2  Situé à Aigues-Mortes et offrant une vue sur l...
# 3  L’établissement Evasion se situe à Aigues-Mort...
# 4  Situé à Aigues-Mortes, l’hébergement La maison...
#
#                                                  url                rating  \
# 0  https://www.booking.com/hotel/fr/la-perle-rose...  Avec une note de 9,9
# 1  https://www.booking.com/hotel/fr/o-36-rempart-...  Avec une note de 9,0
# 2  https://www.booking.com/hotel/fr/nice-home-in-...  Avec une note de 9,0
# 3  https://www.booking.com/hotel/fr/evasion-aigue...  Avec une note de 9,5
# 4  https://www.booking.com/hotel/fr/la-maison-sur...  Avec une note de 9,1
#
#     latitude  longitude
# 0  43.562119   4.185999
# 1  43.565764   4.188757
# 2  43.574800   4.190900
# 3  43.575810   4.182881
# 4  43.565873   4.192959

# %% [markdown]
# ### Création df avec le Top 20 des Hôtels
# ---

# %%
# modifier la colonne rating avec seulement un nombre, new_col = score
df_top20['score']=df_top20['rating'].str.extract(r'(\d+[\.,]?\d*)')[0]

# modifier la virgule en  point pour ensuite faire du SQL et convertir en float
df_top20['score'] = df_top20['score'].str.replace(',', '.').astype(float)

# visu resultat
print(df_top20['score'].head())

# suppression col 'rating' 
df_top20=df_top20.drop(columns=['rating'])

# création df_top20_hotel
liste_top20 = []

for ville in df_top20['ville']:
    trie_ville = df_top20[df_top20['ville'] ==ville] # filtre par ville
    trie_20 = trie_ville.sort_values(by='score').head(20) # trier les 20 premiers meilleurs scores

    liste_top20.append(trie_20)

df_top20_hotel = pd.concat(liste_top20, ignore_index=True)

df_top20_hotel.head()
# Out:
# 0    9.9
# 1    9.0
# 2    9.0
# 3    9.5
# 4    9.1
# Name: score, dtype: float64
#            ville                                               name  \
# 0  Aigues Mortes                      Résidence Odalys Fleur de Sel
# 1  Aigues Mortes               Résidence Odalys Le Mas des Flamants
# 2  Aigues Mortes                                  Hôtel Saint Louis
# 3  Aigues Mortes  Maison T4 -Jardin+ Parking+ Clim -Proche Remparts
# 4  Aigues Mortes  Hôtel les jardins du canal - piscine chauffée ...
#
#                                          description  \
# 0  Situé à Aigues-Mortes, à 5 minutes à pied du c...
# 1  Située à l'extérieur des fortifications d'Aigu...
# 2  Situé dans le cœur historique d'Aigues-Mortes,...
# 3  L’hébergement Maison T4 -Jardin+ Parking+ Clim...
# 4  L’hôtel Canal Aigues Mortes vous accueille sur...
#
#                                                  url   latitude  longitude  \
# 0  https://www.booking.com/hotel/fr/residence-oda...  43.574094   4.179246
# 1  https://www.booking.com/hotel/fr/residence-le-...  43.573794   4.180622
# 2  https://www.booking.com/hotel/fr/saint-louis-a...  43.567220   4.189344
# 3  https://www.booking.com/hotel/fr/maison-t4-jar...  43.565819   4.205353
# 4  https://www.booking.com/hotel/fr/canal-aigues-...  43.572988   4.194825
#
#    score
# 0    8.3
# 1    8.4
# 2    8.5
# 3    8.6
# 4    8.7

# %% [markdown]
# ### Sauvegarde df_top20_hotel en csv
# ---

# %%
df_top20_hotel.to_csv('df_top20_hotel.csv', index=False, encoding='utf-8-sig')
